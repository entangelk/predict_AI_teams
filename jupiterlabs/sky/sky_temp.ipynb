# %% [markdown]
# ## 데이터 확인 작업

# %%
import pandas as pd

# %%
import numpy as np

# %%
df_sale = pd.read_csv("../data/sales.csv")
df_product_info = pd.read_csv("../data/product_info.csv")
df_brand_keyword = pd.read_csv("../data/brand_keyword_cnt.csv")

# %% [markdown]
# - sale.csv
#     - ID : 실제 판매되고 있는 고유 ID
#     - 제품 : 제품 코드
#     - 대분류 / 중분류 / 소분류 / 브랜드
#     - 2022-01-01 ~2023-04-04 : 실제 일별 총 판매금액
# - product_info.csv
#     - 제품 : 제품코드
#     - 제품특성 : 제품특성 데이터(Text)
#     - train.csv에 존재하는 모든 제품 코드가 포함되어 있지 않음. 또는 product_info.csv에 존재하는 제품 코드가 train.csv에 존재하지 않을 수 있음
# - brand_keyword_cnt.csv
#     - 브랜드 코드
#     - 2022-01-01 ~ 2023-04-04 : 브랜드의 연관키워드 언급량을 정규화한 일별 데이터

# %%
df_sale.head()
# Out:
#    ID                제품             대분류             중분류             소분류  \
# 0   0  B002-00001-00001  B002-C001-0002  B002-C002-0007  B002-C003-0038
# 1   1  B002-00002-00001  B002-C001-0003  B002-C002-0008  B002-C003-0044
# 2   2  B002-00002-00002  B002-C001-0003  B002-C002-0008  B002-C003-0044
# 3   3  B002-00002-00003  B002-C001-0003  B002-C002-0008  B002-C003-0044
# 4   4  B002-00003-00001  B002-C001-0001  B002-C002-0001  B002-C003-0003
#
#           브랜드  2022-01-01  2022-01-02  2022-01-03  2022-01-04  ...  \
# 0  B002-00001           0           0           0           0  ...
# 1  B002-00002           0           0           0           0  ...
# 2  B002-00002           0           0           0           0  ...
# 3  B002-00002           0           0           0           0  ...
# 4  B002-00003           0           0           0           0  ...
#
#    2023-03-26  2023-03-27  2023-03-28  2023-03-29  2023-03-30  2023-03-31  \
# ...

# %% [markdown]
# - 각 브랜드의 언급량과 실제 판매금액
# - 각 대분류/중분류/소분류가 뭔지 명확하게 나와 있는가? -> 그렇지 않다면 product_info.csv 안에 텍스트 형태로 되어 있는 제품 특성을 자연어 처리 하여 해당 대/중/소를 예측하기
# - 예측한 결과를 도입한 후, 대/중/소 별로 나누어 추이를 시각화하고 이를 언급량과 비교함
# - 일/월 별로 언급량과 판매량을 시각화하여 이후 상황을 예측
